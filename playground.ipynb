# %%
import numpy as np
import matplotlib.pyplot as plt

pk_data = np.loadtxt("cache_pk.dat").T

print(pk_data)

1420/1350-1420/1050
# Out:
# [[6.70000000e-05 6.83534000e-05 6.97342700e-05 ... 8.92788400e+00
#   9.10824800e+00 9.29229700e+00]
#  [1.42340314e+03 1.45103952e+03 1.47921121e+03 ... 3.55512480e-01
#   3.37222331e-01 3.19867470e-01]]
# -0.30052910052910065

# %%
plt.figure()
plt.plot(np.log10(pk_data[0]),np.log10(pk_data[1]))
plt.show()
